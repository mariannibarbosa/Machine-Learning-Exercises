# %%
import pandas as pd
 
df = pd.read_csv('reviews.csv', encoding = 'ISO-8859-1')
df
# Out:
#                                                     Text  Sentiment
# 0      Once again Mr. Costner has dragged out a movie...          0
# 1      This is an example of why the majority of acti...          0
# 2      First of all I hate those moronic rappers, who...          0
# 3      Not even the Beatles could write songs everyon...          0
# 4      Brass pictures (movies is not a fitting word f...          0
# ...                                                  ...        ...
# 49995  Seeing as the vote average was pretty low, and...          1
# 49996  The plot had some wretched, unbelievable twist...          1
# 49997  I am amazed at how this movie(and most others ...          1
# 49998  A Christmas Together actually came before my t...          1
# 49999  Working-class romantic drama from director Mar...          1
#
# [50000 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       50000 non-null  object
#  1   Sentiment  50000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 781.4+ KB

# %%
df.groupby('Sentiment').describe()
# Out:
#             Text                                                            \
#            count unique                                                top
# Sentiment
# 0          25000  24697  When i got this movie free from my job, along ...
# 1          25000  24884  Loved today's show!!! It was a variety and not...
#
#
#           freq
# Sentiment
# 0            3
# 1            5

# %%
df = df.drop_duplicates()
df.groupby('Sentiment').describe()
# Out:
#             Text                                                            \
#            count unique                                                top
# Sentiment
# 0          24697  24697  Once again Mr. Costner has dragged out a movie...
# 1          24884  24884  I went and saw this movie last night after bei...
#
#
#           freq
# Sentiment
# 0            1
# 1            1

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(stop_words = 'english')

vectorizer
# Out:
# CountVectorizer(stop_words='english')

# %%
x = vectorizer.fit_transform(df['Text'])
y = df['Sentiment']

print(x, y)
# Out:
#   (0, 60837)	1
#   (0, 20760)	4
#   (0, 27355)	1
#   (0, 60747)	1
#   (0, 32532)	1
#   (0, 54016)	1
#   (0, 62182)	1
#   (0, 6358)	1
#   (0, 90761)	1
#   (0, 80230)	1
#   (0, 75685)	1
#   (0, 80908)	1
#   (0, 48921)	1
#   (0, 25209)	2
#   (0, 14850)	3
#   (0, 16217)	1
#   (0, 37473)	2
#   (0, 18067)	2
#   (0, 16195)	2
#   (0, 74010)	1
#   (0, 28425)	1
#   (0, 34950)	1
#   (0, 52008)	1
#   (0, 91787)	1
#   (0, 74021)	1
#   :	:
#   (49580, 67058)	1
#   (49580, 43810)	1
#   (49580, 69411)	1
#   (49580, 18566)	1
#   (49580, 51535)	1
#   (49580, 95767)	1
#   (49580, 79090)	1
#   (49580, 30146)	1
#   (49580, 92319)	1
#   (49580, 100195)	1
#   (49580, 16258)	1
#   (49580, 46477)	1
#   (49580, 34483)	1
#   (49580, 46909)	1
#   (49580, 8394)	1
#   (49580, 44688)	1
#   (49580, 88862)	1
#   (49580, 44689)	1
#   (49580, 63023)	1
#   (49580, 18697)	1
#   (49580, 77548)	1
#   (49580, 97546)	1
#   (49580, 65958)	1
#   (49580, 22388)	1
#   (49580, 76820)	1 0        0
# 1        0
# 2        0
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
x.shape, y.shape, x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((49581, 102810),
#  (49581,),
#  (34706, 102810),
#  (14875, 102810),
#  (34706,),
#  (14875,))

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter = 1000, random_state = 0)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %%
from sklearn.metrics import classification_report

# Assuming you have already trained your model and made predictions
predictions = model.predict(x_test)

# Generate classification report
report = classification_report(y_test, predictions, target_names=['Negative', 'Positive'])

print(report)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.87      0.88      7465
#     Positive       0.87      0.88      0.88      7410
#
#     accuracy                           0.88     14875
#    macro avg       0.88      0.88      0.88     14875
# weighted avg       0.88      0.88      0.88     14875

# %%
review = 'Upfront, Speed" is NOT a complex, intricate, thought provoking, sophisticated whodunit thriller.'
model.predict(tfidf_vectorizer.transform([review]))
# Out:
# array([1])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(stop_words = 'english')
x = tfidf_vectorizer.fit_transform(df['Text'])
y = df['Sentiment']

# %%
print(x)
# Out:
#   (0, 60837)	0.0727617248985425
#   (0, 20760)	0.5292693446794152
#   (0, 27355)	0.10740935740899948
#   (0, 60747)	0.025524483505430472
#   (0, 32532)	0.05615577287869645
#   (0, 54016)	0.08515552497443363
#   (0, 62182)	0.09300993060872753
#   (0, 6358)	0.08577432404472066
#   (0, 90761)	0.08859081957281097
#   (0, 80230)	0.0959264287904932
#   (0, 75685)	0.09894236687276697
#   (0, 80908)	0.0803398342733699
#   (0, 48921)	0.031941323732965675
#   (0, 25209)	0.09122475341400627
#   (0, 14850)	0.2069445507981957
#   (0, 16217)	0.04424448159439139
#   (0, 37473)	0.21662371961490695
#   (0, 18067)	0.22862525465131286
#   (0, 16195)	0.0908254330851284
#   (0, 74010)	0.09246492481161932
#   (0, 28425)	0.06693381627096343
#   (0, 34950)	0.09056941143896065
#   (0, 52008)	0.06203731436157938
#   (0, 91787)	0.03522532469633374
#   (0, 74021)	0.03763585442787639
#   :	:
#   (49580, 67058)	0.12584124212858358
#   (49580, 43810)	0.19490993343284208
#   (49580, 69411)	0.11302026550167509
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter = 1000, random_state = 0)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %%
from sklearn.metrics import classification_report

# Assuming you have already trained your model and made predictions
predictions = model.predict(x_test)

# Generate classification report
report = classification_report(y_test, predictions, target_names=['Negative', 'Positive'])

print(report)
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.90      0.87      0.89      7465
#     Positive       0.88      0.90      0.89      7410
#
#     accuracy                           0.89     14875
#    macro avg       0.89      0.89      0.89     14875
# weighted avg       0.89      0.89      0.89     14875

# %%
review = 'Upfront, Speed" is NOT a complex, intricate, thought provoking, sophisticated whodunit thriller.'
model.predict_proba(vectorizer.transform([review]))
# Out:
# array([[0.00802737, 0.99197263]])

# %%
review = 'Upfront, Speed" is NOT a complex, intricate, thought provoking, sophisticated whodunit thriller.'
model.predict(tfidf_vectorizer.transform([review]))
# Out:
# array([1])

# %%
review = 'The long lines and poor customer service really turned me off.'
model.predict(vectorizer.transform([review]))
# Out:
# array([0])

# %%
review = "Looking for a REAL super bad movie? If you wanna have great fun, don't hesitate and check this one! Ferrigno is incredibly bad but is also the best of this mediocrity."

model.predict(vectorizer.transform([review]))
# Out:
# array([0])

# %%
review = 'Great movie. Really enjoyed it'
model.predict(vectorizer.transform([review]))
# Out:
# array([1])
